# %%
def read_console(path):
    with open(path, 'r') as f:
        console = [l.replace('\n', '') for l in f.readlines()]
    return console

class Directory():
    def __init__(self, name, level, parent):
        self.name = name
        self.level = level
        self.files = []
        self.parent = parent
        self.subdirectories = []

    def get_size(self):
        size = 0
        for file in self.files:
            size += file.get_size()
        for subdirectory in self.subdirectories:
            size += subdirectory.get_size()
        return size

    def access_subdirectory(self, directory_name):
        for subdir in self.subdirectories:
            if subdir.name == directory_name:
                return subdir
        new_subdirectory = self.add_subdirectory(directory_name)
        return new_subdirectory

    def add_subdirectory(self, directory_name):
        if self.get_subdirectory(directory_name):
            return self.get_subdirectory(directory_name)
        else:
            new_subdirectory = Directory(directory_name, self.level+1, self)
            self.subdirectories.append(new_subdirectory)
            return new_subdirectory

    def get_subdirectory(self, directory_name):
        for subdir in self.subdirectories:
            if subdir.name == directory_name:
                return subdir
        return None

    def add_file(self, file_name, file_size):
        self.files.append(File(file_name, file_size, self.level+1))

    def print(self):
        print(f'{"  "*self.level}- {self.name} (dir, size={self.get_size()})')
        for subdir in self.subdirectories:
            subdir.print()
        for file in self.files:
            file.print()

class File():
    def __init__(self, name, size, level):
        self.name = name
        self.size = size
        self.level = level

    def get_size(self):
        return int(self.size)

    def print(self):
        print(f'{"  "*self.level}- {self.name} (file, size={self.size})')


def build_file_system(console):
    root = Directory('/', 0, None)
    active_directory = root

    for command in console:
        if command.startswith('$'):
            command = command.split(" ")[1:]
            if command[0] == 'cd':
                if command[1] == '/':
                    active_directory = root
                elif command[1] == '..':
                    active_directory = active_directory.parent
                else:
                    active_directory = active_directory.access_subdirectory(command[1])
        else:
            size, name = command.split(" ")
            if size == 'dir':
                active_directory.add_subdirectory(name)
            else:
                active_directory.add_file(name, size)
    
    print('Filesystem generated:')
    root.print()
    print()

    return root

def dirs_with_max_size(path, size):
    console = read_console(path)
    root = build_file_system(console)

    total_size = 0
    total_dirs = []
    queue = [root]

    while len(queue) > 0:
        dir = queue.pop(0)
        queue = queue + dir.subdirectories
        if dir.get_size() <= size:
            total_dirs.append(dir.name)
            total_size += dir.get_size()

    print(f'Directories with size less than {size}:')
    print(f'{total_dirs}')
    print()

    return total_size

def delete_smallest_dir(path, full_space, required_space):
    console = read_console(path)
    root = build_file_system(console)

    size_threshold = required_space - (full_space - root.get_size())

    dirs = []
    sizes = []
    queue = [root]

    while len(queue) > 0:
        dir = queue.pop(0)
        queue = queue + dir.subdirectories
        dir_size = dir.get_size()
        if dir_size >= size_threshold:
            dirs.append(dir.name)
            sizes.append(dir_size)

    min_size = min(sizes)
    min_dir = dirs[sizes.index(min_size)]

    return min_size, min_dir

# %%
example = "./example.txt"
test = "./test.txt"

max_size = 100000

example_max_size = dirs_with_max_size(example, max_size)
test_max_size = dirs_with_max_size(test, max_size)

print('##########################################################################################')
print('  *     *        *        *  *        *     *        *   *   *      *      *    *    *    ')
print(f'In the _example case_ the total size of folders with size less than {max_size} is {example_max_size}.')
print(f'In the _test case_ the total size of folders with size less than {max_size} is {test_max_size}.')
print('  *   *     *       *        *        *     *    *      *   *      *       *    *    *    ')
print('##########################################################################################')
# Out:
# Filesystem generated:
# - / (dir, size=48381165)
#   - a (dir, size=94853)
#     - e (dir, size=584)
#       - i (file, size=584)
#     - f (file, size=29116)
#     - g (file, size=2557)
#     - h.lst (file, size=62596)
#   - d (dir, size=24933642)
#     - j (file, size=4060174)
#     - d.log (file, size=8033020)
#     - d.ext (file, size=5626152)
#     - k (file, size=7214296)
#   - b.txt (file, size=14848514)
#   - c.dat (file, size=8504156)
#
# Directories with size less than 100000:
# ['a', 'e']
#
# Filesystem generated:
# - / (dir, size=48748071)
#   - cgw (dir, size=1994012)
#     - jpmf (dir, size=1599361)
#       - ncfcchsz (dir, size=205103)
#         - ntpprbt.pvt (file, size=205103)
#       - rfb (dir, size=331667)
#         - tjtccqtm.qzv (file, size=331667)
#       - tjtccqtm (dir, size=1062591)
#         - jvbb (dir, size=255580)
#           - fbhz (dir, size=255580)
#             - wjj (dir, size=255580)
#               - mgft (file, size=255580)
#         - zgpb (dir, size=258152)
#           - bgpm.gqf (file, size=57622)
#           - jvbb (file, size=44482)
#           - tpc (file, size=156048)
#         - tpc (file, size=175277)
#         - vtgzj.hnb (file, size=304201)
#         - wnq.npz (file, size=69381)
#     - rfb (dir, size=25370)
#       - gjptbqsm.mvm (file, size=25370)
#     - tjtccqtm (dir, size=369281)
#       - pcpqw.wvn (file, size=359767)
#       - wplftrb (file, size=9514)
#   - fbhz (dir, size=31535668)
#     - fbhz (dir, size=590784)
#       - psm.lsv (file, size=363951)
#       - sssdht.pqt (file, size=182275)
#       - zvntd.hvr (file, size=44558)
#     - llfdghs (dir, size=4104794)
#       - hsz (dir, size=1276071)
#         - fbhz (dir, size=163444)
#           - nsrgjtl.dts (file, size=163444)
#         - qsvh (dir, size=572232)
#           - tjtccqtm (dir, size=311932)
#             - dhcmbc.ljq (file, size=311932)
#           - srvhswd.mcg (file, size=260300)
#         - mwlqg.rfg (file, size=72585)
#         - ncfcchsz.cgj (file, size=265089)
#         - vtgzj.hnb (file, size=202721)
#       - mlvl (dir, size=55902)
#         - rfb.jnd (file, size=55902)
#       - tvtqs (dir, size=1995696)
#         - fbhz (dir, size=373263)
#           - ncfcchsz.tfn (file, size=196969)
#           - wzfchcvz.wwv (file, size=176294)
#         - hgr (dir, size=360282)
#           - tjtccqtm (dir, size=360282)
#             - vtgzj.hnb (file, size=360282)
#         - njvsjmmj (dir, size=270925)
#           - gbrjnrh (dir, size=270925)
#             - psm.lsv (file, size=270925)
#         - tjtccqtm (dir, size=421038)
#           - nlqt (dir, size=49935)
#             - tpc (file, size=49935)
#           - tjtccqtm (dir, size=178987)
#             - sgpdvcf (file, size=178987)
#           - vtgzj.hnb (file, size=47866)
#           - zdg.brf (file, size=144250)
#         - vgj (dir, size=213820)
#           - mcbph.srq (file, size=213820)
#         - tpc (file, size=356368)
#       - flg (file, size=126845)
#       - mzz.pbj (file, size=199117)
#       - srvhswd.mcg (file, size=141875)
#       - wrbrmh (file, size=309288)
#     - ncfcchsz (dir, size=808124)
#       - tjtccqtm (dir, size=334824)
#         - ptbdgpn.wnz (file, size=334824)
#       - fbhz (file, size=267915)
#       - zghlv.mtv (file, size=205385)
#     - tbnq (dir, size=4696470)
#       - jvbb (dir, size=994481)
#         - wshhs (dir, size=906056)
#           - bpcv (dir, size=413023)
#             - ncfcchsz.rmg (file, size=108995)
#             - srvhswd.mcg (file, size=304028)
#           - ntptv.hld (file, size=285906)
#           - rfb.wfd (file, size=182940)
#           - wgfmq (file, size=24187)
#         - ztrb (dir, size=88425)
#           - pfzbdqmw (file, size=88425)
#       - nzl (dir, size=2968765)
#         - fbhz (dir, size=317958)
#           - fbhz.pws (file, size=317958)
#         - jzvvr (dir, size=2090358)
#           - srgrvcm (dir, size=1455681)
#             - cfwmvbjq (dir, size=91385)
#               - vtgzj.hnb (file, size=91385)
#             - dqwwtrr (dir, size=566689)
#               - htg.ncm (file, size=151683)
#               - vngq (file, size=178927)
#               - vtgzj.hnb (file, size=236079)
#             - tjtccqtm (dir, size=334582)
#               - psm.lsv (file, size=334582)
#             - grhqhm.bhm (file, size=102903)
#             - qmgtr.qmn (file, size=360122)
#           - dnqfmf.cwg (file, size=292945)
#           - mwtrbv.sfm (file, size=8055)
#           - rfb (file, size=119001)
#           - srvhswd.mcg (file, size=214676)
#         - mghww (dir, size=48114)
#           - msvbqh (file, size=48114)
#         - tnfg (dir, size=172920)
#           - jhn.ghz (file, size=172920)
#         - qcpdd.jfb (file, size=131115)
#         - rqhtgdf.rqf (file, size=208300)
#       - dzwgs (file, size=138692)
#       - gjps.vbz (file, size=70126)
#       - rsshtl.qlg (file, size=196653)
#       - srvhswd.mcg (file, size=110016)
#       - vngq (file, size=217737)
#     - zhj (dir, size=20632494)
#       - dqzgfcd (dir, size=17114523)
#         - ppmbn (dir, size=6037)
#           - vngq (file, size=6037)
#         - rfb (dir, size=1127198)
#           - wdm (dir, size=213994)
#             - psm.lsv (file, size=61473)
#             - srvhswd.mcg (file, size=152521)
#           - nzhchfrv.nst (file, size=293304)
#           - rfb.gfs (file, size=194726)
#           - tpc (file, size=287537)
#           - vtgzj.hnb (file, size=137637)
#         - srlvzvr (dir, size=1248861)
#           - dlp (dir, size=974738)
#             - rfpgt (dir, size=974738)
#               - jvbb.mnq (file, size=281038)
#               - mmjcgss (file, size=312481)
#               - vdpq.qzn (file, size=186883)
#               - wvjrhdq.llv (file, size=194336)
#           - whc.cjc (file, size=274123)
#         - vtdvdgdv (dir, size=704354)
#           - rfb (dir, size=435347)
#             - dprdjqnp.wqc (file, size=196456)
#             - psm.lsv (file, size=67720)
#             - rfb.jrh (file, size=820)
#             - tpc (file, size=170351)
#           - tjtccqtm (dir, size=269007)
#             - bsrvltnf (file, size=269007)
#         - vwhnlp (dir, size=9847279)
#           - fbhz (dir, size=6886041)
#             - dstmnnd (dir, size=521877)
#               - jvbb (dir, size=187235)
#                 - bgrhrn.wmt (file, size=187235)
#               - grbvbw (file, size=334642)
#             - jvbb (dir, size=2622844)
#               - dcszm (dir, size=178161)
#                 - gfc.nss (file, size=178161)
#               - mvcfwwlm (dir, size=284005)
#                 - hvzzlc (file, size=284005)
#               - rfb (dir, size=1483424)
#                 - jvbb (dir, size=611629)
#                   - hlblqv.cbq (file, size=62151)
#                   - jvbb.rgv (file, size=318565)
#                   - ppq.chd (file, size=230913)
#                 - ncfcchsz (dir, size=133380)
#                   - srvhswd.mcg (file, size=133380)
#                 - rhmmtvv (dir, size=270217)
#                   - qms.zrf (file, size=270217)
#                 - fbhz.ccj (file, size=295068)
#                 - mqs (file, size=73713)
#                 - psps.pnc (file, size=99417)
#               - fbhz.bfq (file, size=280304)
#               - jrgqlf (file, size=161981)
#               - psm.lsv (file, size=194182)
#               - zrscw (file, size=40787)
#             - ncfcchsz (dir, size=999864)
#               - bzpz (dir, size=541769)
#                 - tpc (file, size=270136)
#                 - vtgzj.hnb (file, size=271633)
#               - fmhdlm (dir, size=346858)
#                 - mgf.pdm (file, size=273720)
#                 - rfb.lvs (file, size=23453)
#                 - tld.vbh (file, size=49685)
#               - wqctddqc (dir, size=111237)
#                 - ncfcchsz (dir, size=111237)
#                   - vqvs (file, size=111237)
#             - wdpqfl (dir, size=2519282)
#               - fmrclsn (dir, size=907619)
#                 - gzbqm.tnj (file, size=271116)
#                 - jvbb (file, size=216909)
#                 - qnfdzw.slr (file, size=167454)
#                 - tsrzcnjb (file, size=252140)
#               - mwwmbpgr (dir, size=350418)
#                 - jvbb (dir, size=44631)
#                   - tjtccqtm (file, size=44631)
#                 - rqfqbw (dir, size=305787)
#                   - cqpwhrtp (dir, size=305787)
#                     - vjndql.qqv (file, size=305787)
#               - nsf (dir, size=281439)
#                 - ggztzqp (file, size=211811)
#                 - vtgzj.hnb (file, size=69628)
#               - tfpqqjw (dir, size=383565)
#                 - ncfcchsz.dnn (file, size=295011)
#                 - psm.lsv (file, size=88554)
#               - fzgtz.bhg (file, size=258435)
#               - tjtccqtm (file, size=118118)
#               - tjtccqtm.tst (file, size=219688)
#             - dvhhwv.zqz (file, size=65237)
#             - gtbzgp (file, size=156937)
#           - rfb (dir, size=980087)
#             - tgcr (dir, size=198742)
#               - rfb.nsl (file, size=198742)
#             - ncfcchsz (file, size=51633)
#             - psm.lsv (file, size=318667)
#             - qnsldrn (file, size=49231)
#             - sdcmgc.gdt (file, size=240239)
#             - vtgzj.hnb (file, size=121575)
#           - tjtccqtm (dir, size=1765289)
#             - vnwpw (dir, size=1765289)
#               - rfb (dir, size=89621)
#                 - fbhz.vnm (file, size=89621)
#               - tjhvvl (dir, size=894185)
#                 - fbhz (dir, size=213519)
#                   - zpvhg (file, size=213519)
#                 - clmfhnct.wrt (file, size=262643)
#                 - ncfcchsz (file, size=101520)
#                 - vtf.bmc (file, size=169089)
#                 - zgjw.wpn (file, size=72983)
#                 - zlwvcwn.gzf (file, size=74431)
#               - htwmhv (file, size=338543)
#               - lvwjtn.dcz (file, size=18782)
#               - ncfcchsz (file, size=212005)
#               - vtgzj.hnb (file, size=95069)
#               - wsfvhn (file, size=117084)
#           - ncfcchsz.dlh (file, size=30697)
#           - vtgzj.hnb (file, size=185165)
#         - wsmvrf (dir, size=3304776)
#           - ccbw (dir, size=1070281)
#             - crjsgdv (dir, size=420908)
#               - jgstsj (dir, size=251288)
#                 - vtgzj.hnb (file, size=251288)
#               - vngq (file, size=169620)
#             - dthrqpvv (dir, size=234510)
#               - fldrtqh.cbq (file, size=234510)
#             - ncfcchsz (dir, size=177247)
#               - dbt.fsb (file, size=177247)
#             - ppqhd (dir, size=41613)
#               - psm.lsv (file, size=21458)
#               - tjtccqtm.rsn (file, size=20155)
#             - tjtccqtm (dir, size=71907)
#               - psm.lsv (file, size=71907)
#             - ztsmqn (dir, size=124096)
#               - gjzgbrj.sjn (file, size=124096)
#           - nqjpdlc (dir, size=478466)
#             - jvbb (dir, size=266605)
#               - qvwfhw.qvh (file, size=266605)
#             - ltwl (dir, size=68291)
#               - lrgjbbn (dir, size=68291)
#                 - tjtccqtm.rlr (file, size=68291)
#             - lwcgls.qvp (file, size=143570)
#           - sjgjgwb (dir, size=1104456)
#             - ghqtfhcz (dir, size=252002)
#               - gtlfvjpg (dir, size=252002)
#                 - vwz (dir, size=252002)
#                   - tpc (file, size=252002)
#             - jwzmtqff (dir, size=571330)
#               - gsr.mrj (file, size=238465)
#               - gzfcfqn.lbd (file, size=332865)
#             - ddv (file, size=265194)
#             - mzgtdwsg (file, size=15930)
#           - zprqg (dir, size=398566)
#             - nzjwc (file, size=148532)
#             - plznjhb (file, size=179858)
#             - tpc (file, size=70176)
#           - rfb (file, size=253007)
#         - srvhswd.mcg (file, size=225107)
#         - vngq (file, size=353094)
#         - vtgzj.hnb (file, size=297817)
#       - jvbb (dir, size=2958221)
#         - bnllsz (dir, size=216397)
#           - vngq (file, size=216397)
#         - cqdr (dir, size=354586)
#           - psm.lsv (file, size=272746)
#           - tpc (file, size=81840)
#         - jwn (dir, size=799961)
#           - fhl.mrh (file, size=224049)
#           - tpc (file, size=342246)
#           - zmbg (file, size=233666)
#         - lrh (dir, size=139676)
#           - mcdv (file, size=139676)
#         - nfbhj (dir, size=49779)
#           - rfb.tnm (file, size=49779)
#         - nnflrw (dir, size=135683)
#           - hgtjdb (file, size=56516)
#           - psm.lsv (file, size=79167)
#         - rfb (dir, size=65765)
#           - mcdv (file, size=65765)
#         - hrszhbzc.rrq (file, size=293380)
#         - jvbb (file, size=253762)
#         - lchdqwvg (file, size=251152)
#         - srvhswd.mcg (file, size=293144)
#         - vtgzj.hnb (file, size=104936)
#       - ncnhjjs (dir, size=559750)
#         - jvbb (dir, size=9420)
#           - psmrjhmp.dfj (file, size=9420)
#         - ncfcchsz (file, size=276470)
#         - vngq (file, size=273860)
#     - fbhz.fbd (file, size=328535)
#     - fbhz.fbp (file, size=51958)
#     - fcjgf.crj (file, size=37508)
#     - srvhswd.mcg (file, size=222206)
#     - vtgzj.hnb (file, size=62795)
#   - lvrzvt (dir, size=1447647)
#     - qzddwnm (dir, size=214814)
#       - psm.lsv (file, size=214814)
#     - zzwqlz (dir, size=477934)
#       - pcz.ctb (file, size=181990)
#       - tjtccqtm (file, size=258280)
#       - vtgzj.hnb (file, size=37664)
#     - ncfcchsz.zrn (file, size=26201)
#     - ncppww (file, size=267647)
#     - tpc (file, size=345874)
#     - vtgzj.hnb (file, size=115177)
#   - vwlps (dir, size=13546432)
#     - fbhz (dir, size=739)
#       - fbhz (dir, size=739)
#         - mnnzbnl (dir, size=624)
#           - vngq (file, size=624)
#         - zhgrzjt.hlq (file, size=115)
#     - jvbb (dir, size=234261)
#       - jtng.qfh (file, size=149547)
#       - wqqnqpc.crj (file, size=84714)
#     - rfb (dir, size=12306522)
#       - ddcjgrdb (dir, size=949633)
#         - jvbb (dir, size=348073)
#           - jgwzvs (file, size=348073)
#         - rfb (dir, size=601560)
#           - tjtccqtm (dir, size=482447)
#             - rfb (file, size=357579)
#             - srvhswd.mcg (file, size=124868)
#           - tpc (file, size=119113)
#       - lwjvv (dir, size=2074666)
#         - hhjlvjds (dir, size=1039532)
#           - zmzj (dir, size=28824)
#             - vngq (file, size=28824)
#           - przml.gfn (file, size=57297)
#           - psm.lsv (file, size=173735)
#           - srvhswd.mcg (file, size=245882)
#           - tjtccqtm.gnh (file, size=244645)
#           - vngq (file, size=289149)
#         - tvqng (dir, size=136988)
#           - fbhz.wnl (file, size=136988)
#         - zcn (dir, size=239586)
#           - czczrddv (dir, size=239586)
#             - zjwswstd.mdj (file, size=239586)
#         - fbglfwjn (file, size=212416)
#         - tpc (file, size=158555)
#         - vngq (file, size=287589)
#       - mtzbmlnp (dir, size=8400725)
#         - fbhz (dir, size=302746)
#           - lhtc (dir, size=100051)
#             - fbhz.cvg (file, size=100051)
#           - tjtccqtm (dir, size=193182)
#             - psm.lsv (file, size=193182)
#           - vtgzj.hnb (file, size=9513)
#         - jvbb (dir, size=7020257)
#           - rfb (dir, size=2569631)
#             - fgctrfr (dir, size=1501732)
#               - dqjrndw (dir, size=295822)
#                 - tpc (file, size=295822)
#               - rbbw (dir, size=168370)
#                 - hrwj (dir, size=168370)
#                   - zlhhnwrv (dir, size=168370)
#                     - tjtccqtm.dnn (file, size=168370)
#               - zgrrdb (dir, size=84053)
#                 - vtgzj.hnb (file, size=84053)
#               - jmmjds (file, size=103974)
#               - mqr.zhm (file, size=233363)
#               - psm.lsv (file, size=334730)
#               - tjtccqtm (file, size=281420)
#             - tjtccqtm (dir, size=297111)
#               - jpnzcw.srg (file, size=297111)
#             - fbhz (file, size=238032)
#             - jvbb (file, size=306802)
#             - ncfcchsz.lcs (file, size=225954)
#           - tjtccqtm (dir, size=4022810)
#             - jfmc (dir, size=2941860)
#               - fbhz (dir, size=366916)
#                 - rfb (dir, size=304548)
#                   - jhrjt (file, size=304548)
#                 - tqmtbvb (dir, size=62368)
#                   - vngq (file, size=62368)
#               - fjqnrb (dir, size=456257)
#                 - qdrmjmds (dir, size=175406)
#                   - qscgv (dir, size=173814)
#                     - ncfcchsz.nch (file, size=173814)
#                   - rfb (dir, size=1592)
#                     - vtgzj.hnb (file, size=1592)
#                 - rfb (dir, size=237598)
#                   - dvbnmp.bcw (file, size=237598)
#                 - sdtdrmz (dir, size=43253)
#                   - sqdd (file, size=43253)
#               - mpc (dir, size=175855)
#                 - bdsnl (dir, size=175855)
#                   - psm.lsv (file, size=175855)
#               - ncfcchsz (dir, size=1803065)
#                 - ctqnwzgn (dir, size=211637)
#                   - ncfcchsz (file, size=211637)
#                 - dddjjbrs (dir, size=768935)
#                   - lqpsr (dir, size=314159)
#                     - mdzgl.jqd (file, size=314159)
#                   - bjbdh.mtr (file, size=160464)
#                   - jjgblbjc.bvn (file, size=139283)
#                   - szcpzjz.vtv (file, size=155029)
#                 - nbnn (dir, size=218457)
#                   - tpc (file, size=218457)
#                 - tjtccqtm (dir, size=604036)
#                   - rfb (dir, size=240479)
#                     - rblwfbn (file, size=240479)
#                   - vqsjdd (dir, size=253970)
#                     - srvhswd.mcg (file, size=253970)
#                   - tfw (file, size=109587)
#               - vtgzj.hnb (file, size=139767)
#             - qwrd (dir, size=739172)
#               - dgf (dir, size=739172)
#                 - tjtccqtm (dir, size=245596)
#                   - msgtcp (dir, size=245596)
#                     - fbhz (file, size=245596)
#                 - ttqnbdjn (dir, size=153339)
#                   - gvll (dir, size=153339)
#                     - bhhzh (dir, size=153339)
#                       - wcqpmnb.slt (file, size=153339)
#                 - fbsfq.mls (file, size=340237)
#             - tjtccqtm (dir, size=341778)
#               - nzbzjpnl (dir, size=341778)
#                 - dzpjf.wmb (file, size=72123)
#                 - ncfcchsz.qnz (file, size=35136)
#                 - vhq.vrr (file, size=234519)
#           - hvswfzqc.zmc (file, size=224879)
#           - rflsltm.bcc (file, size=202937)
#         - nhfsqbb (dir, size=161184)
#           - tqnct.jvf (file, size=109518)
#           - vngq (file, size=51666)
#         - sjmm (dir, size=499892)
#           - qrpr (dir, size=51657)
#             - tpc (file, size=51657)
#           - rfb (dir, size=185213)
#             - fllcngdc (file, size=185213)
#           - psm.lsv (file, size=263022)
#         - ttsjtcc (dir, size=185477)
#           - fbhz (dir, size=112216)
#             - slzn.jls (file, size=112216)
#           - tjbnz (dir, size=73261)
#             - fbhz.wtd (file, size=73261)
#         - mnrbmhvt (file, size=231169)
#       - nsq (dir, size=93689)
#         - srvhswd.mcg (file, size=93689)
#       - jvbb.nbg (file, size=26416)
#       - pmzdjzmv (file, size=42884)
#       - sgc (file, size=305628)
#       - srvhswd.mcg (file, size=109079)
#       - tpc (file, size=303802)
#     - tjtccqtm (dir, size=232421)
#       - vngq (file, size=232421)
#     - psm.lsv (file, size=347635)
#     - pzzt.prc (file, size=101891)
#     - tjtccqtm.swf (file, size=322963)
#   - vngq (file, size=224312)
#
# Directories with size less than 100000:
# ['rfb', 'fbhz', 'mlvl', 'fbhz', 'nsq', 'ztrb', 'mghww', 'ppmbn', 'nfbhj', 'rfb', 'jvbb', 'mnnzbnl', 'nlqt', 'zmzj', 'qrpr', 'tjbnz', 'cfwmvbjq', 'ppqhd', 'tjtccqtm', 'ltwl', 'rfb', 'lrgjbbn', 'zgrrdb', 'jvbb', 'tqmtbvb', 'sdtdrmz', 'rfb']
#
# ##########################################################################################
#   *     *        *        *  *        *     *        *   *   *      *      *    *    *
# In the _example case_ the total size of folders with size less than 100000 is 95437.
# In the _test case_ the total size of folders with size less than 100000 is 1315285.
#   *   *     *       *        *        *     *    *      *   *      *       *    *    *
# ##########################################################################################

# %%
full_space = 70000000
required_space = 30000000

example_deletion_size, example_deletion_dir = delete_smallest_dir(example, full_space, required_space)
test_deletion_size, test_deletion_dir = delete_smallest_dir(test, full_space, required_space)

print('##########################################################################################')
print('  *     *        *        *  *        *     *        *   *   *      *      *    *    *    ')
print(f'In the _example case_ the smallest deletable directory is {example_deletion_dir} (size={example_deletion_size}).')
print(f'In the _test case_ the smallest deletable directory is {test_deletion_dir} (size={test_deletion_size}).')
print('  *   *     *       *        *        *     *    *      *   *      *       *    *    *    ')
print('##########################################################################################')
# Out:
# Filesystem generated:
# - / (dir, size=48381165)
#   - a (dir, size=94853)
#     - e (dir, size=584)
#       - i (file, size=584)
#     - f (file, size=29116)
#     - g (file, size=2557)
#     - h.lst (file, size=62596)
#   - d (dir, size=24933642)
#     - j (file, size=4060174)
#     - d.log (file, size=8033020)
#     - d.ext (file, size=5626152)
#     - k (file, size=7214296)
#   - b.txt (file, size=14848514)
#   - c.dat (file, size=8504156)
#
# Filesystem generated:
# - / (dir, size=48748071)
#   - cgw (dir, size=1994012)
#     - jpmf (dir, size=1599361)
#       - ncfcchsz (dir, size=205103)
#         - ntpprbt.pvt (file, size=205103)
#       - rfb (dir, size=331667)
#         - tjtccqtm.qzv (file, size=331667)
#       - tjtccqtm (dir, size=1062591)
#         - jvbb (dir, size=255580)
#           - fbhz (dir, size=255580)
#             - wjj (dir, size=255580)
#               - mgft (file, size=255580)
#         - zgpb (dir, size=258152)
#           - bgpm.gqf (file, size=57622)
#           - jvbb (file, size=44482)
#           - tpc (file, size=156048)
#         - tpc (file, size=175277)
#         - vtgzj.hnb (file, size=304201)
#         - wnq.npz (file, size=69381)
#     - rfb (dir, size=25370)
#       - gjptbqsm.mvm (file, size=25370)
#     - tjtccqtm (dir, size=369281)
#       - pcpqw.wvn (file, size=359767)
#       - wplftrb (file, size=9514)
#   - fbhz (dir, size=31535668)
#     - fbhz (dir, size=590784)
#       - psm.lsv (file, size=363951)
#       - sssdht.pqt (file, size=182275)
#       - zvntd.hvr (file, size=44558)
#     - llfdghs (dir, size=4104794)
#       - hsz (dir, size=1276071)
#         - fbhz (dir, size=163444)
#           - nsrgjtl.dts (file, size=163444)
#         - qsvh (dir, size=572232)
#           - tjtccqtm (dir, size=311932)
#             - dhcmbc.ljq (file, size=311932)
#           - srvhswd.mcg (file, size=260300)
#         - mwlqg.rfg (file, size=72585)
#         - ncfcchsz.cgj (file, size=265089)
#         - vtgzj.hnb (file, size=202721)
#       - mlvl (dir, size=55902)
#         - rfb.jnd (file, size=55902)
#       - tvtqs (dir, size=1995696)
#         - fbhz (dir, size=373263)
#           - ncfcchsz.tfn (file, size=196969)
#           - wzfchcvz.wwv (file, size=176294)
#         - hgr (dir, size=360282)
#           - tjtccqtm (dir, size=360282)
#             - vtgzj.hnb (file, size=360282)
#         - njvsjmmj (dir, size=270925)
#           - gbrjnrh (dir, size=270925)
#             - psm.lsv (file, size=270925)
#         - tjtccqtm (dir, size=421038)
#           - nlqt (dir, size=49935)
#             - tpc (file, size=49935)
#           - tjtccqtm (dir, size=178987)
#             - sgpdvcf (file, size=178987)
#           - vtgzj.hnb (file, size=47866)
#           - zdg.brf (file, size=144250)
#         - vgj (dir, size=213820)
#           - mcbph.srq (file, size=213820)
#         - tpc (file, size=356368)
#       - flg (file, size=126845)
#       - mzz.pbj (file, size=199117)
#       - srvhswd.mcg (file, size=141875)
#       - wrbrmh (file, size=309288)
#     - ncfcchsz (dir, size=808124)
#       - tjtccqtm (dir, size=334824)
#         - ptbdgpn.wnz (file, size=334824)
#       - fbhz (file, size=267915)
#       - zghlv.mtv (file, size=205385)
#     - tbnq (dir, size=4696470)
#       - jvbb (dir, size=994481)
#         - wshhs (dir, size=906056)
#           - bpcv (dir, size=413023)
#             - ncfcchsz.rmg (file, size=108995)
#             - srvhswd.mcg (file, size=304028)
#           - ntptv.hld (file, size=285906)
#           - rfb.wfd (file, size=182940)
#           - wgfmq (file, size=24187)
#         - ztrb (dir, size=88425)
#           - pfzbdqmw (file, size=88425)
#       - nzl (dir, size=2968765)
#         - fbhz (dir, size=317958)
#           - fbhz.pws (file, size=317958)
#         - jzvvr (dir, size=2090358)
#           - srgrvcm (dir, size=1455681)
#             - cfwmvbjq (dir, size=91385)
#               - vtgzj.hnb (file, size=91385)
#             - dqwwtrr (dir, size=566689)
#               - htg.ncm (file, size=151683)
#               - vngq (file, size=178927)
#               - vtgzj.hnb (file, size=236079)
#             - tjtccqtm (dir, size=334582)
#               - psm.lsv (file, size=334582)
#             - grhqhm.bhm (file, size=102903)
#             - qmgtr.qmn (file, size=360122)
#           - dnqfmf.cwg (file, size=292945)
#           - mwtrbv.sfm (file, size=8055)
#           - rfb (file, size=119001)
#           - srvhswd.mcg (file, size=214676)
#         - mghww (dir, size=48114)
#           - msvbqh (file, size=48114)
#         - tnfg (dir, size=172920)
#           - jhn.ghz (file, size=172920)
#         - qcpdd.jfb (file, size=131115)
#         - rqhtgdf.rqf (file, size=208300)
#       - dzwgs (file, size=138692)
#       - gjps.vbz (file, size=70126)
#       - rsshtl.qlg (file, size=196653)
#       - srvhswd.mcg (file, size=110016)
#       - vngq (file, size=217737)
#     - zhj (dir, size=20632494)
#       - dqzgfcd (dir, size=17114523)
#         - ppmbn (dir, size=6037)
#           - vngq (file, size=6037)
#         - rfb (dir, size=1127198)
#           - wdm (dir, size=213994)
#             - psm.lsv (file, size=61473)
#             - srvhswd.mcg (file, size=152521)
#           - nzhchfrv.nst (file, size=293304)
#           - rfb.gfs (file, size=194726)
#           - tpc (file, size=287537)
#           - vtgzj.hnb (file, size=137637)
#         - srlvzvr (dir, size=1248861)
#           - dlp (dir, size=974738)
#             - rfpgt (dir, size=974738)
#               - jvbb.mnq (file, size=281038)
#               - mmjcgss (file, size=312481)
#               - vdpq.qzn (file, size=186883)
#               - wvjrhdq.llv (file, size=194336)
#           - whc.cjc (file, size=274123)
#         - vtdvdgdv (dir, size=704354)
#           - rfb (dir, size=435347)
#             - dprdjqnp.wqc (file, size=196456)
#             - psm.lsv (file, size=67720)
#             - rfb.jrh (file, size=820)
#             - tpc (file, size=170351)
#           - tjtccqtm (dir, size=269007)
#             - bsrvltnf (file, size=269007)
#         - vwhnlp (dir, size=9847279)
#           - fbhz (dir, size=6886041)
#             - dstmnnd (dir, size=521877)
#               - jvbb (dir, size=187235)
#                 - bgrhrn.wmt (file, size=187235)
#               - grbvbw (file, size=334642)
#             - jvbb (dir, size=2622844)
#               - dcszm (dir, size=178161)
#                 - gfc.nss (file, size=178161)
#               - mvcfwwlm (dir, size=284005)
#                 - hvzzlc (file, size=284005)
#               - rfb (dir, size=1483424)
#                 - jvbb (dir, size=611629)
#                   - hlblqv.cbq (file, size=62151)
#                   - jvbb.rgv (file, size=318565)
#                   - ppq.chd (file, size=230913)
#                 - ncfcchsz (dir, size=133380)
#                   - srvhswd.mcg (file, size=133380)
#                 - rhmmtvv (dir, size=270217)
#                   - qms.zrf (file, size=270217)
#                 - fbhz.ccj (file, size=295068)
#                 - mqs (file, size=73713)
#                 - psps.pnc (file, size=99417)
#               - fbhz.bfq (file, size=280304)
#               - jrgqlf (file, size=161981)
#               - psm.lsv (file, size=194182)
#               - zrscw (file, size=40787)
#             - ncfcchsz (dir, size=999864)
#               - bzpz (dir, size=541769)
#                 - tpc (file, size=270136)
#                 - vtgzj.hnb (file, size=271633)
#               - fmhdlm (dir, size=346858)
#                 - mgf.pdm (file, size=273720)
#                 - rfb.lvs (file, size=23453)
#                 - tld.vbh (file, size=49685)
#               - wqctddqc (dir, size=111237)
#                 - ncfcchsz (dir, size=111237)
#                   - vqvs (file, size=111237)
#             - wdpqfl (dir, size=2519282)
#               - fmrclsn (dir, size=907619)
#                 - gzbqm.tnj (file, size=271116)
#                 - jvbb (file, size=216909)
#                 - qnfdzw.slr (file, size=167454)
#                 - tsrzcnjb (file, size=252140)
#               - mwwmbpgr (dir, size=350418)
#                 - jvbb (dir, size=44631)
#                   - tjtccqtm (file, size=44631)
#                 - rqfqbw (dir, size=305787)
#                   - cqpwhrtp (dir, size=305787)
#                     - vjndql.qqv (file, size=305787)
#               - nsf (dir, size=281439)
#                 - ggztzqp (file, size=211811)
#                 - vtgzj.hnb (file, size=69628)
#               - tfpqqjw (dir, size=383565)
#                 - ncfcchsz.dnn (file, size=295011)
#                 - psm.lsv (file, size=88554)
#               - fzgtz.bhg (file, size=258435)
#               - tjtccqtm (file, size=118118)
#               - tjtccqtm.tst (file, size=219688)
#             - dvhhwv.zqz (file, size=65237)
#             - gtbzgp (file, size=156937)
#           - rfb (dir, size=980087)
#             - tgcr (dir, size=198742)
#               - rfb.nsl (file, size=198742)
#             - ncfcchsz (file, size=51633)
#             - psm.lsv (file, size=318667)
#             - qnsldrn (file, size=49231)
#             - sdcmgc.gdt (file, size=240239)
#             - vtgzj.hnb (file, size=121575)
#           - tjtccqtm (dir, size=1765289)
#             - vnwpw (dir, size=1765289)
#               - rfb (dir, size=89621)
#                 - fbhz.vnm (file, size=89621)
#               - tjhvvl (dir, size=894185)
#                 - fbhz (dir, size=213519)
#                   - zpvhg (file, size=213519)
#                 - clmfhnct.wrt (file, size=262643)
#                 - ncfcchsz (file, size=101520)
#                 - vtf.bmc (file, size=169089)
#                 - zgjw.wpn (file, size=72983)
#                 - zlwvcwn.gzf (file, size=74431)
#               - htwmhv (file, size=338543)
#               - lvwjtn.dcz (file, size=18782)
#               - ncfcchsz (file, size=212005)
#               - vtgzj.hnb (file, size=95069)
#               - wsfvhn (file, size=117084)
#           - ncfcchsz.dlh (file, size=30697)
#           - vtgzj.hnb (file, size=185165)
#         - wsmvrf (dir, size=3304776)
#           - ccbw (dir, size=1070281)
#             - crjsgdv (dir, size=420908)
#               - jgstsj (dir, size=251288)
#                 - vtgzj.hnb (file, size=251288)
#               - vngq (file, size=169620)
#             - dthrqpvv (dir, size=234510)
#               - fldrtqh.cbq (file, size=234510)
#             - ncfcchsz (dir, size=177247)
#               - dbt.fsb (file, size=177247)
#             - ppqhd (dir, size=41613)
#               - psm.lsv (file, size=21458)
#               - tjtccqtm.rsn (file, size=20155)
#             - tjtccqtm (dir, size=71907)
#               - psm.lsv (file, size=71907)
#             - ztsmqn (dir, size=124096)
#               - gjzgbrj.sjn (file, size=124096)
#           - nqjpdlc (dir, size=478466)
#             - jvbb (dir, size=266605)
#               - qvwfhw.qvh (file, size=266605)
#             - ltwl (dir, size=68291)
#               - lrgjbbn (dir, size=68291)
#                 - tjtccqtm.rlr (file, size=68291)
#             - lwcgls.qvp (file, size=143570)
#           - sjgjgwb (dir, size=1104456)
#             - ghqtfhcz (dir, size=252002)
#               - gtlfvjpg (dir, size=252002)
#                 - vwz (dir, size=252002)
#                   - tpc (file, size=252002)
#             - jwzmtqff (dir, size=571330)
#               - gsr.mrj (file, size=238465)
#               - gzfcfqn.lbd (file, size=332865)
#             - ddv (file, size=265194)
#             - mzgtdwsg (file, size=15930)
#           - zprqg (dir, size=398566)
#             - nzjwc (file, size=148532)
#             - plznjhb (file, size=179858)
#             - tpc (file, size=70176)
#           - rfb (file, size=253007)
#         - srvhswd.mcg (file, size=225107)
#         - vngq (file, size=353094)
#         - vtgzj.hnb (file, size=297817)
#       - jvbb (dir, size=2958221)
#         - bnllsz (dir, size=216397)
#           - vngq (file, size=216397)
#         - cqdr (dir, size=354586)
#           - psm.lsv (file, size=272746)
#           - tpc (file, size=81840)
#         - jwn (dir, size=799961)
#           - fhl.mrh (file, size=224049)
#           - tpc (file, size=342246)
#           - zmbg (file, size=233666)
#         - lrh (dir, size=139676)
#           - mcdv (file, size=139676)
#         - nfbhj (dir, size=49779)
#           - rfb.tnm (file, size=49779)
#         - nnflrw (dir, size=135683)
#           - hgtjdb (file, size=56516)
#           - psm.lsv (file, size=79167)
#         - rfb (dir, size=65765)
#           - mcdv (file, size=65765)
#         - hrszhbzc.rrq (file, size=293380)
#         - jvbb (file, size=253762)
#         - lchdqwvg (file, size=251152)
#         - srvhswd.mcg (file, size=293144)
#         - vtgzj.hnb (file, size=104936)
#       - ncnhjjs (dir, size=559750)
#         - jvbb (dir, size=9420)
#           - psmrjhmp.dfj (file, size=9420)
#         - ncfcchsz (file, size=276470)
#         - vngq (file, size=273860)
#     - fbhz.fbd (file, size=328535)
#     - fbhz.fbp (file, size=51958)
#     - fcjgf.crj (file, size=37508)
#     - srvhswd.mcg (file, size=222206)
#     - vtgzj.hnb (file, size=62795)
#   - lvrzvt (dir, size=1447647)
#     - qzddwnm (dir, size=214814)
#       - psm.lsv (file, size=214814)
#     - zzwqlz (dir, size=477934)
#       - pcz.ctb (file, size=181990)
#       - tjtccqtm (file, size=258280)
#       - vtgzj.hnb (file, size=37664)
#     - ncfcchsz.zrn (file, size=26201)
#     - ncppww (file, size=267647)
#     - tpc (file, size=345874)
#     - vtgzj.hnb (file, size=115177)
#   - vwlps (dir, size=13546432)
#     - fbhz (dir, size=739)
#       - fbhz (dir, size=739)
#         - mnnzbnl (dir, size=624)
#           - vngq (file, size=624)
#         - zhgrzjt.hlq (file, size=115)
#     - jvbb (dir, size=234261)
#       - jtng.qfh (file, size=149547)
#       - wqqnqpc.crj (file, size=84714)
#     - rfb (dir, size=12306522)
#       - ddcjgrdb (dir, size=949633)
#         - jvbb (dir, size=348073)
#           - jgwzvs (file, size=348073)
#         - rfb (dir, size=601560)
#           - tjtccqtm (dir, size=482447)
#             - rfb (file, size=357579)
#             - srvhswd.mcg (file, size=124868)
#           - tpc (file, size=119113)
#       - lwjvv (dir, size=2074666)
#         - hhjlvjds (dir, size=1039532)
#           - zmzj (dir, size=28824)
#             - vngq (file, size=28824)
#           - przml.gfn (file, size=57297)
#           - psm.lsv (file, size=173735)
#           - srvhswd.mcg (file, size=245882)
#           - tjtccqtm.gnh (file, size=244645)
#           - vngq (file, size=289149)
#         - tvqng (dir, size=136988)
#           - fbhz.wnl (file, size=136988)
#         - zcn (dir, size=239586)
#           - czczrddv (dir, size=239586)
#             - zjwswstd.mdj (file, size=239586)
#         - fbglfwjn (file, size=212416)
#         - tpc (file, size=158555)
#         - vngq (file, size=287589)
#       - mtzbmlnp (dir, size=8400725)
#         - fbhz (dir, size=302746)
#           - lhtc (dir, size=100051)
#             - fbhz.cvg (file, size=100051)
#           - tjtccqtm (dir, size=193182)
#             - psm.lsv (file, size=193182)
#           - vtgzj.hnb (file, size=9513)
#         - jvbb (dir, size=7020257)
#           - rfb (dir, size=2569631)
#             - fgctrfr (dir, size=1501732)
#               - dqjrndw (dir, size=295822)
#                 - tpc (file, size=295822)
#               - rbbw (dir, size=168370)
#                 - hrwj (dir, size=168370)
#                   - zlhhnwrv (dir, size=168370)
#                     - tjtccqtm.dnn (file, size=168370)
#               - zgrrdb (dir, size=84053)
#                 - vtgzj.hnb (file, size=84053)
#               - jmmjds (file, size=103974)
#               - mqr.zhm (file, size=233363)
#               - psm.lsv (file, size=334730)
#               - tjtccqtm (file, size=281420)
#             - tjtccqtm (dir, size=297111)
#               - jpnzcw.srg (file, size=297111)
#             - fbhz (file, size=238032)
#             - jvbb (file, size=306802)
#             - ncfcchsz.lcs (file, size=225954)
#           - tjtccqtm (dir, size=4022810)
#             - jfmc (dir, size=2941860)
#               - fbhz (dir, size=366916)
#                 - rfb (dir, size=304548)
#                   - jhrjt (file, size=304548)
#                 - tqmtbvb (dir, size=62368)
#                   - vngq (file, size=62368)
#               - fjqnrb (dir, size=456257)
#                 - qdrmjmds (dir, size=175406)
#                   - qscgv (dir, size=173814)
#                     - ncfcchsz.nch (file, size=173814)
#                   - rfb (dir, size=1592)
#                     - vtgzj.hnb (file, size=1592)
#                 - rfb (dir, size=237598)
#                   - dvbnmp.bcw (file, size=237598)
#                 - sdtdrmz (dir, size=43253)
#                   - sqdd (file, size=43253)
#               - mpc (dir, size=175855)
#                 - bdsnl (dir, size=175855)
#                   - psm.lsv (file, size=175855)
#               - ncfcchsz (dir, size=1803065)
#                 - ctqnwzgn (dir, size=211637)
#                   - ncfcchsz (file, size=211637)
#                 - dddjjbrs (dir, size=768935)
#                   - lqpsr (dir, size=314159)
#                     - mdzgl.jqd (file, size=314159)
#                   - bjbdh.mtr (file, size=160464)
#                   - jjgblbjc.bvn (file, size=139283)
#                   - szcpzjz.vtv (file, size=155029)
#                 - nbnn (dir, size=218457)
#                   - tpc (file, size=218457)
#                 - tjtccqtm (dir, size=604036)
#                   - rfb (dir, size=240479)
#                     - rblwfbn (file, size=240479)
#                   - vqsjdd (dir, size=253970)
#                     - srvhswd.mcg (file, size=253970)
#                   - tfw (file, size=109587)
#               - vtgzj.hnb (file, size=139767)
#             - qwrd (dir, size=739172)
#               - dgf (dir, size=739172)
#                 - tjtccqtm (dir, size=245596)
#                   - msgtcp (dir, size=245596)
#                     - fbhz (file, size=245596)
#                 - ttqnbdjn (dir, size=153339)
#                   - gvll (dir, size=153339)
#                     - bhhzh (dir, size=153339)
#                       - wcqpmnb.slt (file, size=153339)
#                 - fbsfq.mls (file, size=340237)
#             - tjtccqtm (dir, size=341778)
#               - nzbzjpnl (dir, size=341778)
#                 - dzpjf.wmb (file, size=72123)
#                 - ncfcchsz.qnz (file, size=35136)
#                 - vhq.vrr (file, size=234519)
#           - hvswfzqc.zmc (file, size=224879)
#           - rflsltm.bcc (file, size=202937)
#         - nhfsqbb (dir, size=161184)
#           - tqnct.jvf (file, size=109518)
#           - vngq (file, size=51666)
#         - sjmm (dir, size=499892)
#           - qrpr (dir, size=51657)
#             - tpc (file, size=51657)
#           - rfb (dir, size=185213)
#             - fllcngdc (file, size=185213)
#           - psm.lsv (file, size=263022)
#         - ttsjtcc (dir, size=185477)
#           - fbhz (dir, size=112216)
#             - slzn.jls (file, size=112216)
#           - tjbnz (dir, size=73261)
#             - fbhz.wtd (file, size=73261)
#         - mnrbmhvt (file, size=231169)
#       - nsq (dir, size=93689)
#         - srvhswd.mcg (file, size=93689)
#       - jvbb.nbg (file, size=26416)
#       - pmzdjzmv (file, size=42884)
#       - sgc (file, size=305628)
#       - srvhswd.mcg (file, size=109079)
#       - tpc (file, size=303802)
#     - tjtccqtm (dir, size=232421)
#       - vngq (file, size=232421)
#     - psm.lsv (file, size=347635)
#     - pzzt.prc (file, size=101891)
#     - tjtccqtm.swf (file, size=322963)
#   - vngq (file, size=224312)
#
# ##########################################################################################
#   *     *        *        *  *        *     *        *   *   *      *      *    *    *
# In the _example case_ the smallest deletable directory is d (size=24933642).
# In the _test case_ the smallest deletable directory is vwhnlp (size=9847279).
#   *   *     *       *        *        *     *    *      *   *      *       *    *    *
# ##########################################################################################
